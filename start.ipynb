# %%
pip install -U huggingface_hub

# %%
# !python scripts/prepare_hf_character_data.py --output-dir data
# Out:
# storyplay_sft: 9736 条
# gryphe_sft: 9736 条
# character_sft_combined: 9736 条（原始 19472 条，已去重）
# storyplay_dpo: 3425 条
# storyplay_dpo: 跳过 3 条 rejected 为空的样本
# 已写入数据集注册: /workspace/Character/data/dataset_info.json

# %%
# !bash scripts/run_train.sh
# Out:
# [ERROR] Missing /workspace/Character/data/character_sharegpt.json. Run prepare_character_data.py first.
